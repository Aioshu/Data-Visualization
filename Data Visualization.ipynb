# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=np.linspace(2,10,14)# (range,total values)
y=np.linspace(2,15,14)
plt.plot(x,y,"b+")

# %%
plt.figure(1)

plt.subplot(341)
plt.plot(x,y,"b+")

plt.subplot(342)
plt.plot(x,y**2,"g*")

plt.subplot(343)
plt.plot(x,y**2,"g*")

plt.subplot(344)
plt.plot(x,y**2,"g*")


plt.figure(2)

plt.subplot(121)
plt.plot(x,y**3,"y+")


plt.subplot(122)
plt.plot(x,y/3,"p-")

plt.show()

# %%
data=pd.read_csv("Datavisual/global_sales_data/market_fact.csv")

# %%
data.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
data.shape
# Out:
# (8399, 10)

# %%
data.describe()
# Out:
#               Sales     Discount  Order_Quantity        Profit  Shipping_Cost  \
# count   8399.000000  8399.000000     8399.000000   8399.000000    8399.000000
# mean    1775.878179     0.049671       25.571735    181.184424      12.838557
# std     3585.050525     0.031823       14.481071   1196.653371      17.264052
# min        2.240000     0.000000        1.000000 -14140.700000       0.490000
# 25%      143.195000     0.020000       13.000000    -83.315000       3.300000
# 50%      449.420000     0.050000       26.000000     -1.500000       6.070000
# 75%     1709.320000     0.080000       38.000000    162.750000      13.990000
# max    89061.050000     0.250000       50.000000  27220.690000     164.730000
#
#        Product_Base_Margin
# count          8336.000000
# mean              0.512513
# std               0.135589
# min               0.350000
# 25%               0.380000
# 50%               0.520000
# 75%               0.590000
# max               0.850000

# %%
data.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
# Box plot
# Bar Graph
# Histogram
#

# %% [markdown]
# ## Boxplot

# %%
plt.boxplot(data["Order_Quantity"])
plt.show() # start with zero and end at 50, Median is about 25

# %%
plt.boxplot(data["Sales"])
plt.show()

# %%
# distribution of sales is not even similar there are many ups and downs

# %%
data.Sales.describe()
# Out:
# count     8399.000000
# mean      1775.878179
# std       3585.050525
# min          2.240000
# 25%        143.195000
# 50%        449.420000
# 75%       1709.320000
# max      89061.050000
# Name: Sales, dtype: float64

# %%
# to handle the situation we take log on y axis y then the very higher values is scale down to lower value and we will able to visualise it more clearly

# %%
# Using Subplot 
plt.subplot(121)
plt.boxplot(data.Sales)

plt.subplot(122)
plt.yscale("log")
plt.boxplot(data.Sales)

plt.show()

# %% [markdown]
# # Histogram

# %%
plt.hist(data.Sales)
plt.xlim(0,40000)
plt.xlabel("sales Values")
plt.ylabel("Count")
plt.title("Count/sales")
plt.show()

# %%
# loging the y scale 
plt.hist(data.Sales)
plt.yscale("log")
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
plt.scatter(data.Sales,data.Profit)
plt.show()
# max data lies in 0-20000

# %% [markdown]
# # Working with Images Data

# %% [markdown]
# Matplotlib also read the Image using plt.imread() function.

# %%
image=plt.imread("Datavisual/country_analysis.png")

# %%
plt.imshow(image)
plt.show()

# %%
print(type(image))
print(image.shape)
print(image.dtype)
# Out:
# <class 'numpy.ndarray'>
# (766, 891, 4)
# float32

# %%
import seaborn as sns

# %%
sns.distplot(data.Shipping_Cost)
plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(data.Shipping_Cost[:200],rug=True)
plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(data.Shipping_Cost,hist=False)
plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#plt.figure(1)
plt.subplot(2,2,1)
sns.distplot(data.Sales)

plt.subplot(2,2,2)
sns.distplot(data.Profit)

#plt.figure(2)
plt.subplot(2,2,3)
sns.distplot(data.Sales[:200])

plt.subplot(2,2,4)
sns.distplot(data.Profit[:200])

plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ...

# %% [markdown]
# # Boxplot

# %% [markdown]
# Boxplot is used to analyise univariate data .

# %%
sns.boxplot(data.Order_Quantity)
plt.title("Order Quantity ")
plt.show()

# %%
# for y axis
sns.boxplot(y=data.Order_Quantity)
plt.title("Order Quantity ")
plt.show()

# %% [markdown]
# # Visualize the bivariate Distribution

# %%
# They are joint distribution and done by sns.jointplot()

# %%
sns.jointplot("Sales","Profit",data)
#plt.xlabel("Sales")
#plt.ylabel("Profit")
#plt.title("Profit Vs Sales")
plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
temp=data[(data["Profit"]<15000) & (data["Sales"]<20000)]
sns.jointplot("Sales","Profit",temp)
plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ## Plotting Pairwise Relationships
#
# You'll find it helpful to plot pairwise relationships between multiple numeric variables. For e.g., here we have taken the prices of some popular cryptocurrencies such as bitcoin, litecoin, ethereum, monero, neo, quantum and ripple.
#
# Now, the crypto enthusiasts would know that the prices of these currencies vary with each other. If bitcoin goes up, the others will likely follow suit, etc.
#
#
# Now, say you want to trade in some currencies. Given a set of cryptocurrencies, how will you decide when and which one to buy/sell? It will be helpful to analyse past data and identify some trends in these currencies.

# %%
btc=pd.read_csv("Datavisual/crypto_data/bitcoin_price.csv")
ether=pd.read_csv("Datavisual/crypto_data/ethereum_price.csv")
ltc=pd.read_csv("Datavisual/crypto_data/litecoin_price.csv")
monero=pd.read_csv("Datavisual/crypto_data/monero_price.csv")
neo=pd.read_csv("Datavisual/crypto_data/neo_price.csv")
quantum=pd.read_csv("Datavisual/crypto_data/qtum_price.csv")
ripple=pd.read_csv("Datavisual/crypto_data/ripple_price.csv")

# %%
print(btc.columns)
print(ether.columns)
print(ltc.columns)
print(monero.columns)
print(neo.columns)
print(quantum.columns)
print(ripple.columns)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')

# %%
btc.columns=btc.columns.map(lambda x:str(x)+"_btc")
ether.columns=ether.columns.map(lambda x:str(x)+"_et")
ltc.columns=ltc.columns.map(lambda x:str(x)+"_ltc")
neo.columns=neo.columns.map(lambda x:str(x)+"_neo")
quantum.columns=quantum.columns.map(lambda x:str(x)+"_qt")
monero.columns=monero.columns.map(lambda x:str(x)+"_mon")
ripple.columns=ripple.columns.map(lambda x:str(x)+"_rip")

# %%
print(btc.columns)
# Out:
# Index(['Date_btc', 'Open_btc', 'High_btc', 'Low_btc', 'Close_btc',
#        'Volume_btc', 'Market Cap_btc'],
#       dtype='object')

# %%
btc.head()
# Out:
#        Date_btc  Open_btc  High_btc  Low_btc  Close_btc     Volume_btc  \
# 0  Nov 07, 2017   7023.10   7253.32  7023.10    7144.38  2,326,340,000
# 1  Nov 06, 2017   7403.22   7445.77  7007.31    7022.76  3,111,900,000
# 2  Nov 05, 2017   7404.52   7617.48  7333.19    7407.41  2,380,410,000
# 3  Nov 04, 2017   7164.48   7492.86  7031.28    7379.95  2,483,800,000
# 4  Nov 03, 2017   7087.53   7461.29  7002.94    7207.76  3,369,860,000
#
#     Market Cap_btc
# 0  117,056,000,000
# 1  123,379,000,000
# 2  123,388,000,000
# 3  119,376,000,000
# 4  118,084,000,000

# %%
# Merging All files
m1=pd.merge(btc,ether,how="inner",left_on="Date_btc",right_on="Date_et")
m1.head()
m2=pd.merge(m1,ltc,how="inner",left_on="Date_btc",right_on="Date_ltc")
m3=pd.merge(m2,monero,how="inner",left_on="Date_btc",right_on="Date_mon")
m4=pd.merge(m3,neo,how="inner",left_on="Date_btc",right_on="Date_neo")
m5=pd.merge(m4,quantum,how="inner",left_on="Date_btc",right_on="Date_qt")
crypto=pd.merge(m5,ripple,how="inner",left_on="Date_btc",right_on="Date_rip")
crypto.head()
# Out:
#        Date_btc  Open_btc  High_btc  Low_btc  Close_btc     Volume_btc  \
# 0  Nov 07, 2017   7023.10   7253.32  7023.10    7144.38  2,326,340,000
# 1  Nov 06, 2017   7403.22   7445.77  7007.31    7022.76  3,111,900,000
# 2  Nov 05, 2017   7404.52   7617.48  7333.19    7407.41  2,380,410,000
# 3  Nov 04, 2017   7164.48   7492.86  7031.28    7379.95  2,483,800,000
# 4  Nov 03, 2017   7087.53   7461.29  7002.94    7207.76  3,369,860,000
#
#     Market Cap_btc       Date_et  Open_et  High_et      ...        Close_qt  \
# 0  117,056,000,000  Nov 07, 2017   298.57   304.84      ...           11.21
# 1  123,379,000,000  Nov 06, 2017   296.43   305.42      ...           10.44
# 2  123,388,000,000  Nov 05, 2017   300.04   301.37      ...           10.13
# 3  119,376,000,000  Nov 04, 2017   305.48   305.48      ...           10.05
# 4  118,084,000,000  Nov 03, 2017   288.50   308.31      ...           10.38
#
#      Volume_qt Market Cap_qt      Date_rip  Open_rip  High_rip   Low_rip  \
# ...

# %%
crypto.head()
# Out:
#        Date_btc  Open_btc  High_btc  Low_btc  Close_btc     Volume_btc  \
# 0  Nov 07, 2017   7023.10   7253.32  7023.10    7144.38  2,326,340,000
# 1  Nov 06, 2017   7403.22   7445.77  7007.31    7022.76  3,111,900,000
# 2  Nov 05, 2017   7404.52   7617.48  7333.19    7407.41  2,380,410,000
# 3  Nov 04, 2017   7164.48   7492.86  7031.28    7379.95  2,483,800,000
# 4  Nov 03, 2017   7087.53   7461.29  7002.94    7207.76  3,369,860,000
#
#     Market Cap_btc       Date_et  Open_et  High_et      ...        Close_qt  \
# 0  117,056,000,000  Nov 07, 2017   298.57   304.84      ...           11.21
# 1  123,379,000,000  Nov 06, 2017   296.43   305.42      ...           10.44
# 2  123,388,000,000  Nov 05, 2017   300.04   301.37      ...           10.13
# 3  119,376,000,000  Nov 04, 2017   305.48   305.48      ...           10.05
# 4  118,084,000,000  Nov 03, 2017   288.50   308.31      ...           10.38
#
#      Volume_qt Market Cap_qt      Date_rip  Open_rip  High_rip   Low_rip  \
# ...

# %%
crypto.shape
# Out:
# (168, 49)

# %%
curr=crypto[["Close_btc","Close_et","Close_ltc","Close_mon","Close_neo","Close_qt"]]

# %%
curr.head()
# Out:
#    Close_btc  Close_et  Close_ltc  Close_mon  Close_neo  Close_qt
# 0    7144.38    294.66      61.30      99.76      26.23     11.21
# 1    7022.76    298.89      55.17     102.92      26.32     10.44
# 2    7407.41    296.26      54.75      86.35      26.38     10.13
# 3    7379.95    300.47      55.04      87.30      26.49     10.05
# 4    7207.76    305.71      56.18      87.99      26.82     10.38

# %%
# Using sns.pairplot()

# %%
sns.pairplot(curr)
plt.show()

# %%
curr.corr()
# Out:
#            Close_btc  Close_et  Close_ltc  Close_mon  Close_neo  Close_qt
# Close_btc   1.000000  0.449322   0.657963   0.697058   0.734797  0.381921
# Close_et    0.449322  1.000000   0.490281   0.539489   0.481910  0.791373
# Close_ltc   0.657963  0.490281   1.000000   0.793368   0.641385  0.447711
# Close_mon   0.697058  0.539489   0.793368   1.000000   0.668514  0.518419
# Close_neo   0.734797  0.481910   0.641385   0.668514   1.000000  0.556858
# Close_qt    0.381921  0.791373   0.447711   0.518419   0.556858  1.000000

# %%
plt.figure(figsize=(10,8))

# heatmap
sns.heatmap(curr.corr(), cmap="YlGnBu", annot=True)
plt.show()

# %% [markdown]
#  # Dealing with Categorical Data

# %%
sns.set(style="white")

# %%
market_df=pd.read_csv("Datavisual/global_sales_data/market_fact.csv")
customer_df=pd.read_csv("Datavisual/global_sales_data/cust_dimen.csv")
product_df=pd.read_csv("Datavisual/global_sales_data/prod_dimen.csv")
shipping_df=pd.read_csv("Datavisual/global_sales_data/shipping_dimen.csv")
orders_df=pd.read_csv("Datavisual/global_sales_data/orders_dimen.csv")

# %%
market_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
customer_df.tail()
# Out:
#         Customer_Name Province Region Customer_Segment    Cust_id
# 1827   NICOLE BRENNAN  ALBERTA   WEST         CONSUMER  Cust_1828
# 1828    JASON FORTUNE  ALBERTA   WEST        CORPORATE  Cust_1829
# 1829     HARRY GREENE  ALBERTA   WEST        CORPORATE  Cust_1830
# 1830  GRANT DONATELLI  ALBERTA   WEST         CONSUMER  Cust_1831
# 1831       MICK BROWN  ALBERTA   WEST         CONSUMER  Cust_1832

# %%
product_df.head()
# Out:
#   Product_Category            Product_Sub_Category Prod_id
# 0  OFFICE SUPPLIES          STORAGE & ORGANIZATION  Prod_1
# 1  OFFICE SUPPLIES                      APPLIANCES  Prod_2
# 2  OFFICE SUPPLIES  BINDERS AND BINDER ACCESSORIES  Prod_3
# 3       TECHNOLOGY    TELEPHONES AND COMMUNICATION  Prod_4
# 4        FURNITURE              OFFICE FURNISHINGS  Prod_5

# %%
shipping_df.head()
# Out:
#    Order_ID       Ship_Mode   Ship_Date Ship_id
# 0         3     REGULAR AIR  20-10-2010   SHP_1
# 1       293  DELIVERY TRUCK  02-10-2012   SHP_2
# 2       293     REGULAR AIR  03-10-2012   SHP_3
# 3       483     REGULAR AIR  12-07-2011   SHP_4
# 4       515     REGULAR AIR  30-08-2010   SHP_5

# %%
orders_df.head()
# Out:
#    Order_ID  Order_Date Order_Priority Ord_id
# 0         3  13-10-2010            LOW  Ord_1
# 1       293  01-10-2012           HIGH  Ord_2
# 2       483  10-07-2011           HIGH  Ord_3
# 3       515  28-08-2010  NOT SPECIFIED  Ord_4
# 4       613  17-06-2011           HIGH  Ord_5

# %%
sns.boxplot(y=market_df.Sales)
plt.yscale("log")
plt.show()

# %%
df=pd.merge(market_df,product_df,how="inner",on="Prod_id")
df.tail()
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 8394  Ord_5467  Prod_14  SHP_7639  Cust_1803   5964.19      0.10
# 8395   Ord_825  Prod_14  SHP_1132   Cust_247  27663.92      0.05
# 8396  Ord_5368  Prod_14  SHP_7497  Cust_1795  17279.62      0.04
# 8397  Ord_1765  Prod_14  SHP_2446   Cust_595  14647.26      0.07
# 8398  Ord_3610  Prod_14  SHP_4998  Cust_1266   1759.65      0.06
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# 8394              33   988.20          24.49                 0.46
# 8395               8  -391.92          24.49                 0.37
# 8396              40  4176.25          24.49                 0.52
# 8397              25  5485.15          24.49                 0.37
# 8398               3 -2213.75          24.49                 0.50
#
#      Product_Category Product_Sub_Category
# 8394       TECHNOLOGY      COPIERS AND FAX
# 8395       TECHNOLOGY      COPIERS AND FAX
# 8396       TECHNOLOGY      COPIERS AND FAX
# ...

# %%
sns.boxplot(df.Product_Category,df.Sales)
plt.yscale("log")
plt.show()

# %%
# showing that tech and furniture showing better result  .Note that each order can have multiple units of products sold, so 
#Sales being higher/lower may be due to price per unit or the number of units.

#Let's now plot the other important variable - Profit.

# %%
df.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin',
#        'Product_Category', 'Product_Sub_Category'],
#       dtype='object')

# %%
sns.boxplot(df.Product_Category,df.Profit)
plt.show()

# %%
# profit has some outliers.
temp=df[(df.Profit>-1000) & (df.Profit<1000)]
sns.boxplot(temp.Product_Category,temp.Profit)
plt.show()

# %%
# tech is showing most sales but here now it is also happening that most loss also occuring here as 25% is under the loss.

# %%
plt.figure(figsize=(10,8))

#Subplot .1
plt.subplot(121)
sns.boxplot(df.Product_Category,df.Sales)
plt.yscale("log")
plt.title("Sales")

#Subplot .2
plt.subplot(122)
sns.boxplot(temp.Product_Category,temp.Profit)
plt.title("Profit")

plt.show()

# %% [markdown]
# # Finding Profit For Another categorial Variables

# %%
# Customer Variables

# %%
data=pd.merge(temp,customer_df,how="inner",on="Cust_id")
data.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 3  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 4  Ord_2978  Prod_16  SHP_4112  Cust_1088   305.05      0.04              27
#
#    Profit  Shipping_Cost  Product_Base_Margin Product_Category  \
# 0  -30.51           3.60                 0.56  OFFICE SUPPLIES
# 1    4.56           0.93                 0.54  OFFICE SUPPLIES
# 2  729.34          14.30                 0.37  OFFICE SUPPLIES
# 3  -47.64           6.15                 0.37  OFFICE SUPPLIES
# 4   23.12           3.37                 0.57  OFFICE SUPPLIES
#
#             Product_Sub_Category  Customer_Name Province   Region  \
# ...

# %%
sns.boxplot(data.Customer_Segment,data.Profit)
plt.show()

# %% [markdown]
# ### We can visual the distribution  on 2 Categorical Variables, using "hue=" arguement

# %%
plt.figure(figsize=(12,8),dpi=80,facecolor="w",edgecolor="k",num=5)
sns.boxplot(data.Customer_Segment,data.Profit,hue=data.Product_Category)
plt.show()

# %% [markdown]
# Across all customer segments, the product category ```Technology``` seems to be doing fairly well, though ```Furniture``` is incurring losses across all segments.
#
# Now say you are curious to know why certain orders are making huge losses.
#
# One of your hypothesis is that the *shipping cost is too high in some orders*. You can **plot derived variables** as well, such as *shipping cost as percentage of sales amount*.

# %%
sns.boxplot(data['Product_Category'], 100*data['Shipping_Cost']/data['Sales'])
plt.ylabel("100*(Shipping cost/Sales)")
plt.show()

# %%
# Plotting Aggregate values across Categories

# %% [markdown]
# ### Bar Plots - Mean, Median and Count Plots
#
#
# Bar plots are used to **display aggregated values** of a variable, rather than entire distributions. This is especially useful when you have a lot of data which is difficult to visualise in a single figure.
#
# For example, say you want to visualise and *compare the average Sales across Product Categories*. The ```sns.barplot()``` function can be used to do that.

# %%
# bar plot with default statistic=mean

sns.barplot(data.Product_Category,data.Profit)
plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(data.Product_Category,data.Sales)
plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(12,8))

plt.subplot(121)
sns.barplot(data.Product_Category,data.Sales)
plt.title("Average_Sales")


plt.subplot(122)
sns.barplot(data.Product_Category,data.Sales,estimator=np.median)
plt.title("Median_Sales")

plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Adding another categorial variable

# %%
plt.figure(figsize=(12,8),dpi=80)
sns.barplot(data.Customer_Segment,data.Profit,hue=data.Product_Category,estimator=np.median)
plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# The plot neatly shows the median profit across product categories and customer segments. It says that:
# - On an average, only Technology products in Small Business and Corporate (customer) categories are profitable.
# - Furniture is incurring losses across all Customer Segments
#
#
# Compare this to the boxplot we had created above - though the bar plots contains 'lesser information' than the boxplot, it is more revealing.

# %%
# when we have large number of categories its better to put it on y-axis.

# %%
plt.figure(figsize=(12,8))
sns.barplot(data.Profit,data.Product_Sub_Category,estimator=np.median)
plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# sub Categories incurring heavier lOsses- Copiers and fax,bookcases,Tables,chairs and chairmats.

# %% [markdown]
#  # PLoting count of observation using sns.countplot()

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=data.Product_Sub_Category)
plt.show()

# %% [markdown]
# # TimeSeries Visualization using sns.tsplot()

# %%
[df.columns]
# Out:
# [Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#         'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin',
#         'Product_Category', 'Product_Sub_Category'],
#        dtype='object')]

# %% [markdown]
# ### Problem Statement : Visualize the Sales,Profit,Shipping Cost over time.

# %%
orders_df.head()
# Out:
#    Order_ID  Order_Date Order_Priority Ord_id
# 0         3  13-10-2010            LOW  Ord_1
# 1       293  01-10-2012           HIGH  Ord_2
# 2       483  10-07-2011           HIGH  Ord_3
# 3       515  28-08-2010  NOT SPECIFIED  Ord_4
# 4       613  17-06-2011           HIGH  Ord_5

# %%
df=pd.merge(market_df,orders_df,how="inner",on="Ord_id")
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 2  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 3  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 4  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
#
#     Profit  Shipping_Cost  Product_Base_Margin  Order_ID  Order_Date  \
# 0   -30.51           3.60                 0.56     36262  27-07-2010
# 1  1148.90           2.50                 0.59     36262  27-07-2010
# 2   -47.64           6.15                 0.37     36262  27-07-2010
# 3     4.56           0.93                 0.54     20513  07-07-2009
# 4   729.34          14.30                 0.37     39682  09-11-2010
#
#   Order_Priority
# 0  NOT SPECIFIED
# 1  NOT SPECIFIED
# 2  NOT SPECIFIED
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8399 entries, 0 to 8398
# Data columns (total 13 columns):
# Ord_id                 8399 non-null object
# Prod_id                8399 non-null object
# Ship_id                8399 non-null object
# Cust_id                8399 non-null object
# Sales                  8399 non-null float64
# Discount               8399 non-null float64
# Order_Quantity         8399 non-null int64
# Profit                 8399 non-null float64
# Shipping_Cost          8399 non-null float64
# Product_Base_Margin    8336 non-null float64
# Order_ID               8399 non-null int64
# Order_Date             8399 non-null object
# Order_Priority         8399 non-null object
# dtypes: float64(5), int64(2), object(6)
# memory usage: 918.6+ KB

# %%
df.Order_Date=pd.to_datetime(df.Order_Date)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8399 entries, 0 to 8398
# Data columns (total 13 columns):
# Ord_id                 8399 non-null object
# Prod_id                8399 non-null object
# Ship_id                8399 non-null object
# Cust_id                8399 non-null object
# Sales                  8399 non-null float64
# Discount               8399 non-null float64
# Order_Quantity         8399 non-null int64
# Profit                 8399 non-null float64
# Shipping_Cost          8399 non-null float64
# Product_Base_Margin    8336 non-null float64
# Order_ID               8399 non-null int64
# Order_Date             8399 non-null datetime64[ns]
# Order_Priority         8399 non-null object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 918.6+ KB

# %%
# since on each day multiple order are placed so we will take the aggregate sales using a metric mean,median,etc, and then create 
# the timeSeries Plot

# We will group by Order_By and sum sales on each day.

# %%
time_df=df.groupby("Order_Date")["Sales"].sum()
time_df.head()
# Out:
# Order_Date
# 2009-01-01    1052.8400
# 2009-01-02    5031.9000
# 2009-01-03    7288.1375
# 2009-01-04    6188.4245
# 2009-01-05    2583.3300
# Name: Sales, dtype: float64

# %%
# time Series Plot
# figure size
import warnings
warnings.filterwarnings("ignore")
plt.figure(figsize=(12,8))

sns.tsplot(data=time_df)
plt.ylabel("Sales")
plt.xlabel("time")
plt.show()

# %% [markdown]
# ### Using Derived Date Metrics for Visualisation
#
# It is often helpful to use derived variables from date such as month and year and using them to identify hidden patterns.

# %%
# extract month
df["month"]=df.Order_Date.dt.month
df["month"]=df.Order_Date.dt.month

# %%
df["Year"]=df.Order_Date.dt.year
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 2  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 3  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 4  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
#
#     Profit  Shipping_Cost  Product_Base_Margin  Order_ID Order_Date  \
# 0   -30.51           3.60                 0.56     36262 2010-07-27
# 1  1148.90           2.50                 0.59     36262 2010-07-27
# 2   -47.64           6.15                 0.37     36262 2010-07-27
# 3     4.56           0.93                 0.54     20513 2009-07-07
# 4   729.34          14.30                 0.37     39682 2010-09-11
#
#   Order_Priority  month  Year
# 0  NOT SPECIFIED      7  2010
# 1  NOT SPECIFIED      7  2010
# ...

# %%
# Average Sales across year and month:
df_time=df.groupby(["Year","month"])["Sales"].mean()
df_time.head()
# Out:
# Year  month
# 2009  1        1898.475090
#       2        2116.510723
#       3        2258.661599
#       4        2374.155868
#       5        1922.317055
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(12,8))
sns.tsplot(df_time)
plt.xlabel("time")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# Another way to visualize "Sales" across month and year .We can pivot the month column to create a wide -format dataframe ,and the plot heatmap.

# %%
year_month_sales=pd.pivot_table(df,values="Sales",index="Year",columns="month",aggfunc="mean")
year_month_sales
# Out:
# month           1            2            3            4            5   \
# Year
# 2009   1898.475090  2116.510723  2258.661599  2374.155868  1922.317055
# 2010   1549.664361  1591.532297  1708.934944  1461.935539  1440.393540
# 2011   1321.671562  1733.378070  1822.860614  2062.716921  1822.033936
# 2012   2220.831551  2438.166961  1578.284028  1325.253694  1865.744629
#
# month           6            7            8            9            10  \
# Year
# 2009   1548.093259  1909.084469  1827.095921  1717.295494  2203.961070
# 2010   1695.397085  1272.653408  1277.917503  2216.599136  1927.250907
# 2011   1655.599644  1515.576260  1471.700741  1430.616748  1851.404564
# 2012   2192.228263  1824.935942  1090.950643  1628.963780  1636.951775
#
# month           11           12
# Year
# 2009   1502.192743  2209.047484
# 2010   1806.324648  1869.720956
# 2011   2161.479056  1672.187881
# 2012   1935.183039  1747.047528

# %%
plt.figure(figsize=(12,8))
sns.heatmap(year_month_sales,cmap="YlGnBu")
plt.show()
